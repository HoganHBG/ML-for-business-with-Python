# %% [markdown]
# <a href="https://colab.research.google.com/github/HoganHBG/ML-for-business-with-Python/blob/master/Claas_0_cs68_zesstimate_hw_starter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
from statsmodels.sandbox.regression.predstd import wls_prediction_std
from vega_datasets import data
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
housing_data =  pd.read_csv('https://raw.githubusercontent.com/cjflanagan/cs68/master/housing.csv')

# %%
# Data description available here: https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data?select=data_description.txt
housing_data.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
housing_data.shape
# Out:
# (1460, 81)

# %%
sns.scatterplot(y='SalePrice', x='LotArea', data=housing_data)

# %%
sns.lmplot(y='SalePrice', x='LotArea', data=housing_data)

# %%
y = housing_data['SalePrice']
y
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
X = housing_data[['LotArea', 'BedroomAbvGr']]
X.head()
# Out:
#    LotArea  BedroomAbvGr
# 0     8450             3
# 1     9600             3
# 2    11250             3
# 3     9550             3
# 4    14260             4

# %%
X = sm.add_constant(X)
X.head()
# Out:
#    const  LotArea  BedroomAbvGr
# 0    1.0     8450             3
# 1    1.0     9600             3
# 2    1.0    11250             3
# 3    1.0     9550             3
# 4    1.0    14260             4

# %%
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.089
# Model:                            OLS   Adj. R-squared:                  0.087
# Method:                 Least Squares   F-statistic:                     70.78
# Date:                Thu, 02 Jul 2020   Prob (F-statistic):           4.62e-30
# Time:                        00:17:17   Log-Likelihood:                -18476.
# No. Observations:                1460   AIC:                         3.696e+04
# Df Residuals:                    1457   BIC:                         3.697e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         1.215e+05   7368.475     16.493      0.000    1.07e+05    1.36e+05
# ...

# %%
# Have fun!!

# %%
# %%html
# <img src='https://sd.keepcalms.com/i/keep-calm-and-have-fun-explore.png' />
# Out:
# <img src='https://sd.keepcalms.com/i/keep-calm-and-have-fun-explore.png' />

# %%
X = housing_data[['MSSubClass','LotArea', 'GrLivArea', 'OverallCond','OverallQual' ,'TotRmsAbvGrd', 'BedroomAbvGr', 'KitchenAbvGr','FullBath' ,'HalfBath','Fireplaces', 'GarageCars' ,'WoodDeckSF','EnclosedPorch' ,'YearBuilt', 'BsmtFinSF1','TotalBsmtSF']]
X.head()
# Out:
#    MSSubClass  LotArea  GrLivArea  ...  YearBuilt  BsmtFinSF1  TotalBsmtSF
# 0          60     8450       1710  ...       2003         706          856
# 1          20     9600       1262  ...       1976         978         1262
# 2          60    11250       1786  ...       2001         486          920
# 3          70     9550       1717  ...       1915         216          756
# 4          60    14260       2198  ...       2000         655         1145
#
# [5 rows x 17 columns]

# %%
X = sm.add_constant(X)
X.head()
# Out:
#    const  MSSubClass  LotArea  ...  YearBuilt  BsmtFinSF1  TotalBsmtSF
# 0    1.0          60     8450  ...       2003         706          856
# 1    1.0          20     9600  ...       1976         978         1262
# 2    1.0          60    11250  ...       2001         486          920
# 3    1.0          70     9550  ...       1915         216          756
# 4    1.0          60    14260  ...       2000         655         1145
#
# [5 rows x 18 columns]

# %%
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.805
# Model:                            OLS   Adj. R-squared:                  0.802
# Method:                 Least Squares   F-statistic:                     349.1
# Date:                Thu, 02 Jul 2020   Prob (F-statistic):               0.00
# Time:                        01:25:22   Log-Likelihood:                -17352.
# No. Observations:                1460   AIC:                         3.474e+04
# Df Residuals:                    1442   BIC:                         3.484e+04
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -8.575e+05   1.08e+05     -7.912      0.000   -1.07e+06   -6.45e+05
# ...
